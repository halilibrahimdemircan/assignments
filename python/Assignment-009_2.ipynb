# %%
# Task 1 :Write a short Python program that asks the user to enter Celsius temperature 
#(it can be a decimal number), converts the entered temperature into Fahrenheit degree and prints the result.

# %%
celcius = int(input("What is the temperature(celcius): "))
fahrenheit = celcius*1.8 + 32
print(" The temperature is {} fahrenheit". format(fahrenheit))
# Out:
# What is the temperature(celcius): 10
#  The temperature is 50.0 fahrenheit

# %%
# Task 2 : Write a short Python program that asks the user to enter a distance (it can be a decimal number)
# in kilometers, converts the entered distance into miles and prints the result.

# %%
km = int(input("What is the distance(km): "))
mile = km*0.621371192
print(" The distance is {} miles". format(mile))
# Out:
# What is the distance(km): 50
#  The distance is 31.0685596 miles

# %%
x = int(input("Bir sayı giriniz: "))
x += 5
print(" 5 more of x  : ", x)
# Out:
# Bir sayı giriniz: 23
#  5 more of x  :  28

# %%
print('it\'s funny to learn Python')
# Out:
# it's funny to learn Python
